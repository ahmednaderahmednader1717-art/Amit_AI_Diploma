# %%
userName="Ahmed"
print("My name is", userName)
# print("My name is", userName)
# Out:
# My name is Ahmed

# %%
'''
print("Await")
print("Await")
print("Await")
'''

print("machine learninig")

# print("deep learning")
# print("deep learning")
# print("deep learning")
# Out:
# machine learninig

# %%
print("my name is {0} and iam {1} years old".format("Ahmed", 21))
print("my name is {} and iam {} years old".format("Ahmed", 21))
print("my name is {x} and iam {y} years old".format(x="Ahmed", y=21))

x= "Ahmed"
y= 21
print(f"my name is {x} and iam {y} years old")
# Out:
# my name is Ahmed and iam 21 years old
# my name is Ahmed and iam 21 years old
# my name is Ahmed and iam 21 years old
# my name is Ahmed and iam 21 years old

# %%
userName=input("Enter Your Name: ")
userAge=input("Enter Your Age: ")
courseName="Amit AI Course"
print(f"My name is {userName} and iam {userAge} years old and iam engaged to {courseName}")
# Out:
# My name is Ahmed  and iam Nader years old and iam engaged to Amit AI Course

# %%
x="Ahmed"
print(x.upper())
# Out:
# AHMED

# %%
x=[1,2, True,""]
print(type(x))
# Out:
# <class 'list'>

# %%
name="hello world"
print(name.replace("world","Amit").__len__())
# Out:
# 10

# %%
info = ["iam learning", " python"]
print(''.join(info))
# Out:
# iam learning python

# %%
list_1 =[1,2,3,4,'amit','learning',True,[1,2,3,'True',['ml','dl','ds']]]
print(type(list_1))
list_1[7][4][2]="test"
print(list_1[7][4][2])
print(list(list_1[7][3]))
# Out:
# <class 'list'>
# test
# ['T', 'r', 'u', 'e']

# %%
list_one=["amit","learning","python"]
list_two=["ahmed","nader","21"]
list_one.append("ml")
print(list_one)
list_one.insert(1,"dl")
print(list_one)
list_one.extend(list_two)
print(list_one)
# Out:
# ['amit', 'learning', 'python', 'ml']
# ['amit', 'dl', 'learning', 'python', 'ml']
# ['amit', 'dl', 'learning', 'python', 'ml', 'ahmed', 'nader', '21']

# %%
list_one=["amit","learning","python"]
list_one.remove("amit")
print(list_one)
list_one.pop(0)
print(list_one)
list_one.append("ml")
print(list_one)
# Out:
# ['learning', 'python']
# ['python']
# ['python', 'ml']

# %%
name =input("please enter ur name: ")
age =input("please enter ur age: ")
print(f"my name is {name} and iam {age} years old")
# Out:
# my name is AHmed NAder and iam 21 years old

# %%
list_one=["ahmed","nader","21"]
delitem=input("please enter any value to be deleted: ")
list_one.remove(delitem)
print(list_one)
# Out:
# ['nader', '21']
