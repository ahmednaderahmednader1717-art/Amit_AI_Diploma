# %%
def addtion(x,y):
    return x + y


x= int(input("please enter the first number: "))
y = int(input("please enter the second number: "))
z= addtion(x,y)
print(z)
# Out:
# 30

# %%
def sutraction(x,y):
    return x-y

x= int(input("please enter the first number: "))
y = int(input("please enter the second number: "))
z= sutraction(x,y)
print(z)
# Out:
# 5

# %%
def multiplication(x,y):
    return x*y

x= int(input("please enter the first number: "))
y = int(input("please enter the second number: "))
z= multiplication(x,y)
print(z)
# Out:
# 100

# %%
def division(x,y):
    return x/y

x= int(input("please enter the first number: "))
y = int(input("please enter the second number: "))
z= division(x,y)
print(z)
# Out:
# 2.5

# %%
operations = input("Enter the operations")

x= int(input("please enter the first number: "))
y = int(input("please enter the second number: "))

if operations == "+":
    result = addtion(x,y)
elif operations == "-":
    result = subtraction(x,y)
elif operations == "*":
    result = multiplication(x,y)
elif operations == "/":
    result = division(x,y)
else:
    print("Invalid operation")

print(result)
# Out:
# 30

# %%
from even_odd import get_numbers_type

x = int(input("please enter the list length: "))
list_1 = []

for i in range(x):
    num = int(input(f"Enter number {i+1}: "))
    list_1.append(num)

even_numbers = []
odd_numbers = []


get_numbers_type(list_1)

print("even_numbers:", even_numbers)
print("odd_numbers:", odd_numbers)

# %%
def function_1 (name,age):
    print("Hello my name is ",name,"and my age is ",age)
    
name = input("enter your name : ")
age = input("enter your age : ")
function_1(name,age)
# Out:
# Hello my name is : 21 and my age is : ahmed
